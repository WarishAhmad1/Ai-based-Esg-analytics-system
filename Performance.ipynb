# %% [markdown]
# 1. KPI Overview

# %%
import pandas as pd
import plotly.express as px

df = pd.read_csv("company_esg_financial_dataset.csv")

df = df.dropna(subset=["CompanyName","Year","ESG_Overall"])

df["Year"] = pd.to_numeric(df["Year"], errors="coerce")
df["ESG_Overall"] = pd.to_numeric(df["ESG_Overall"], errors="coerce")

df = df.dropna()

latest = df.sort_values(["CompanyName","Year"]).groupby("CompanyName").tail(1)

# KPI calculations
avg_score = latest["ESG_Overall"].mean()
top_company = latest.sort_values("ESG_Overall", ascending=False).iloc[0]
low_company = latest.sort_values("ESG_Overall", ascending=True).iloc[0]

# Print KPIs
print("Average ESG Score:", round(avg_score,2))
print("Top Company:", top_company["CompanyName"], top_company["ESG_Overall"])
print("Lowest Company:", low_company["CompanyName"], low_company["ESG_Overall"])


# 🔥 Graph added (KPI Comparison)
kpi_df = pd.DataFrame({
    "Metric": ["Average ESG", "Top ESG", "Lowest ESG"],
    "Score": [
        avg_score,
        top_company["ESG_Overall"],
        low_company["ESG_Overall"]
    ]
})

fig = px.bar(
    kpi_df,
    x="Metric",
    y="Score",
    title="KPI Comparison",
    text="Score"
)

fig.update_traces(textposition="outside")

fig.show()
# Out:
# Average ESG Score: 57.83
# Top Company: Company_478 98.0
# Lowest Company: Company_311 14.3

# %% [markdown]
# 2. Company-wise ESG Score

# %%
import pandas as pd
import plotly.express as px

df = pd.read_csv("company_esg_financial_dataset.csv")

df = df.dropna(subset=["CompanyName","Year","ESG_Overall"])

latest = df.sort_values(["CompanyName","Year"]).groupby("CompanyName").tail(1)

def category(score):
    if score >= 75:
        return "High"
    elif score >= 50:
        return "Medium"
    else:
        return "Low"

latest["Category"] = latest["ESG_Overall"].apply(category)

fig = px.bar(
    latest.sort_values("ESG_Overall", ascending=False),
    x="CompanyName",
    y="ESG_Overall",
    color="Category",
    title="Company ESG Score"
)

fig.show()

# %% [markdown]
# 3. ESG Category Distribution

# %%
import pandas as pd
import plotly.express as px

df = pd.read_csv("company_esg_financial_dataset.csv")

df = df.dropna(subset=["CompanyName","Year","ESG_Overall"])

latest = df.sort_values(["CompanyName","Year"]).groupby("CompanyName").tail(1)

def category(score):
    if score >= 75:
        return "High"
    elif score >= 50:
        return "Medium"
    else:
        return "Low"

latest["Category"] = latest["ESG_Overall"].apply(category)

counts = latest["Category"].value_counts().reset_index()
counts.columns = ["Category","Count"]

fig = px.pie(
    counts,
    names="Category",
    values="Count",
    hole=0.4,
    title="ESG Category Distribution"
)

fig.show()
